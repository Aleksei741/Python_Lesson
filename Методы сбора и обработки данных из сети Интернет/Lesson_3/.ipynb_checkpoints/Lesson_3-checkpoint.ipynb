# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import re

# %%
main_link_hh = 'https://hh.ru'
main_link_sj = 'https://www.superjob.ru'

# %%
header = {'Accept': '*/*',
          'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0'
}

# %% [markdown]
# В переменную function_name вводить желаемую должность

# %%
function_name = 'python'

# %%
function_name_correct = function_name#.replace(' ', '+')

# %%
parameter = {
    'text': function_name_correct,
    'search_period': "30" #1,3,7,30
}

# %%
session = requests.session()

# %%
def parse_hh(html):
    data = list()
    vacancys_block = html.find('div', {'class':"vacancy-serp"})
    pattern = re.compile('vacancy-serp-item.*')
    # print(vacancys_block)
    vacancy_block = vacancys_block.findChildren('div', {'class':pattern}, recursive=False)
    for vacancy in vacancy_block:
        dict_ = {}
        
        dict_['name'] = vacancy.find('a', {'class': 'bloko-link HH-LinkModifier'}).text
        dict_['href'] = vacancy.find('a', {'class': 'bloko-link HH-LinkModifier'})['href']
        #dict_['company'] = vacancy.find('a', {'class': 'bloko-link bloko-link_secondary'}).text
        dict_['company'] = vacancy.findAll('div', {'class': 'vacancy-serp-item__meta-info'})[0].text.replace('\xa0', ' ')
        dict_['position'] = vacancy.findAll('div', {'class': 'vacancy-serp-item__meta-info'})[1].text
        dict_['site'] = main_link_hh

        finance = vacancy.find('div', {'class': 'vacancy-serp-item__sidebar'}).text.replace('\xa0', ' ')
        if not finance:
            dict_['finance_min'] = None
            dict_['finance_max'] = None
            dict_['valuta'] = None
        else:        
            pattern_number = re.compile('[0-9]{1,3}\s{1}[0-9]{3}')
            pattren_valuta = re.compile('руб\.|USD|EUR|KZT|грн.')
            pattren_ot = re.compile('от')
            pattren_do = re.compile('до')

            number = re.findall(pattern_number, finance)
            valuta = re.findall(pattren_valuta, finance)
            if valuta:
                valuta = valuta[0]
            

            if len(number) == 2:
                dict_['finance_min'] = int(number[0].replace(' ', ''))
                dict_['finance_max'] = int(number[1].replace(' ', ''))
                dict_['valuta'] = valuta
            elif len(number) == 1:
                ot = re.findall(pattren_ot, finance)
                do = re.findall(pattren_do, finance)
                if not do:
                    dict_['finance_min'] = int(number[0].replace(' ', ''))
                    dict_['finance_max'] = None
                    dict_['valuta'] = valuta
                elif not ot:
                    dict_['finance_min'] = None
                    dict_['finance_max'] = int(number[0].replace(' ', ''))
                    dict_['valuta'] = valuta
                    
        #print(dict_)
        data.append(dict_) 
    return data

# %%
def parse_sj(html):
    data = list()
    vacancy_blocks = html.find('div', {'style':"display:block"})
    #print(vacancy_blocks)
    
    vacancy_block = vacancy_blocks.findChildren('div', {'class':'_3zucV _2GPIV f-test-vacancy-item i6-sc _3VcZr'}, recursive=False)
    #print(vacancy_block)
    
    for vacancy in vacancy_block:
        dict_ = {}
        
        pattern_name = re.compile('icMQ_ _1QIBo .*')
        name_module = vacancy.find('a', {'class': pattern_name})
        dict_['name'] = name_module.text
        dict_['href'] = main_link_sj + name_module['href']
        
        pattern_company = re.compile('icMQ_ _205Zx .*')
        company_module = vacancy.find('a', {'class': pattern_company})
        if company_module:
            dict_['company'] = company_module.text
        else:
            dict_['company'] = None
        
        pattern_position = re.compile('_3mfro f-test-text-company-item-location.*')
        position_module = vacancy.find('span', {'class': pattern_position})
        if company_module:
            dict_['position'] = position_module.text
        else:
            dict_['position'] = None

        
        dict_['site'] = main_link_sj

        
        pattern_finance = re.compile('_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz')
        finance_module = vacancy.find('span', {'class': pattern_finance})
        finance = finance_module.text.replace('\xa0', ' ')
        #dict_['finance'] = finance
        if finance == 'По договорённости':
            dict_['finance_min'] = None
            dict_['finance_max'] = None
            dict_['valuta'] = None
        else:        
            pattern_number = re.compile('[0-9]{1,3}\s{1}[0-9]{3}')
            pattren_valuta = re.compile('₽')
            pattren_ot = re.compile('от')
            pattren_do = re.compile('до')

            number = re.findall(pattern_number, finance)
            valuta = re.findall(pattren_valuta, finance)
            if valuta:
                valuta = valuta[0] 
            if len(number) == 2:
                dict_['finance_min'] = int(number[0].replace(' ', ''))
                dict_['finance_max'] = int(number[1].replace(' ', ''))
                dict_['valuta'] = valuta
            elif len(number) == 1:
                ot = re.findall(pattren_ot, finance)
                do = re.findall(pattren_do, finance)
                if not do:
                    dict_['finance_min'] = int(number[0].replace(' ', ''))
                    dict_['finance_max'] = None
                    dict_['valuta'] = valuta
                elif not ot:
                    dict_['finance_min'] = None
                    dict_['finance_max'] = int(number[0].replace(' ', ''))
                    dict_['valuta'] = valuta
                
        #print(dict_)
        data.append(dict_) 
    return data

# %%
def get_html(link, header):
    proxies = {
    "http": ""
    }
    #response = session.get(link, headers=header, proxies=proxies)
    response = session.get(link, headers=header)
    
    #print(response.status_code)
    html = bs(response.text,'lxml')
    print(response.status_code)
    return html

# %%
def get_next_link_hh(html):
    bufer = html.find('a', {'class':"bloko-button HH-Pager-Controls-Next HH-Pager-Control"})
    if bufer:
        return main_link_hh + bufer['href']
        link = bufer['href']
    else:
        return ''

# %%
def get_next_link_sj(html):
    bufer = html.find('a', {'class':"icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-Dalshe"})
    if bufer:
        return main_link_sj + bufer['href']
        link = bufer['href']
    else:
        return ''

# %%
result = list()
link = main_link_hh + f'/search/vacancy?search_period=30&salary=&st=searchVacancy&text={function_name_correct}'
#link = 'https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=Data+science&page=16'
while link:
    print(link)
    html = get_html(link, header)
    #print(html)
    result = result + parse_hh(html)
    link = get_next_link_hh(html)
    
link = main_link_sj + f'/vacancy/search/?keywords={function_name}&geo[c][0]=1'
while link:
    print(link)
    html = get_html(link, header)
    result = result + parse_sj(html)
    link = ''
    link = get_next_link_sj(html)
# Out:
# https://hh.ru/search/vacancy?search_period=30&salary=&st=searchVacancy&text=python
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=1
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=2
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=3
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=4
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=5
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=6
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=7
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=8
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=9
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=10
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=11
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=12
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=13
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=14
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=15
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=16
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=17
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=18
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=19
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=20
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=21
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=22
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=23
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=24
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=25
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=26
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=27
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=28
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=29
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=30
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=31
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=32
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=33
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=34
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=35
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=36
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=37
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=38
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=39
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=40
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=41
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=42
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=43
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=44
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=45
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=46
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=47
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=48
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=49
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=50
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=51
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=52
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=53
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=54
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=55
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=56
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=57
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=58
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=59
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=60
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=61
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=62
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=63
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=64
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=65
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=66
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=67
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=68
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=69
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=70
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=71
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=72
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=73
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=74
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=75
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=76
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=77
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=78
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=79
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=80
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=81
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=82
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=83
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=84
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=85
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=86
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=87
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=88
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=89
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=90
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=91
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=92
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=93
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=94
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=95
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=96
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=97
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=98
# 200
# https://hh.ru/search/vacancy?L_is_autosearch=false&clusters=true&enable_snippets=true&search_period=30&text=python&page=99
# 200
# https://www.superjob.ru/vacancy/search/?keywords=python&geo[c][0]=1
# 200
# https://www.superjob.ru/vacancy/search/?keywords=python&page=2
# 200
# https://www.superjob.ru/vacancy/search/?keywords=python&page=3
# 200
# https://www.superjob.ru/vacancy/search/?keywords=python&page=4
# 200

# %%
len(result)
# Out:
# 2079

# %% [markdown]
# Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД
#
# Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введенной суммы
#
# *Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта

# %%
bufer_result = result

# %%
import pandas as pd

# %%
from pymongo import MongoClient

# %%
def open_DataBase():
    client  = MongoClient('localhost',27017)
    db = client['Jobs']
    #vacancy = db.vacancy
    return db

def сhoose_catalog(db):
    vacancy = db.vacancy
    return vacancy

def create_unique_key_vacancy_DataBase(vacancy):
    vacancy.create_index([("name", 1), ("company", 1)], unique=True)

def save_data_DataBase(vacancy, data):
    for i in data:
        try:
            vacancy.insert_one(i)
            print('ok')
        except:
            print('duplicate')
        
def save_one_data_DataBase(vacancy, data):
    for i in data:
        print('=============================================================')
        print(i)
        try:
            vacancy.insert_one(i)
            print('OK')
        except:
            print('ERROR, duplicate')
        print('=============================================================')
        
def reade_DataBase(vacancy):    
    objects = list(vacancy.find({}))
    return objects      
        
def search_in_DataBase(vacancy, min_finance):    
    objects = list(vacancy.find({'$or': 
                       [
                           {'finance_min': {'$gte': min_finance}},
                           {'$and': [{'finance_min': {'$lte': min_finance}}, {'finance_max': {'$gte': min_finance}}]}, 
                           {'finance_max': {'$gte': min_finance}}
                       ]
                      }
                     )
                    )
    return objects

def cleare_DataBase(vacancy):
    vacancy.remove({})

# %%
db = open_DataBase()
vacancy = сhoose_catalog(db)

# %%
create_unique_key_vacancy_DataBase(vacancy)

# %%
#cleare_DataBase(vacancy)
# Out:
# c:\users\a.kraev\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.

# %%
save_one_data_DataBase(vacancy, result)
# Out:
# =============================================================
# {'name': 'Junior data scientist (ML разработчик, python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35660654?query=python', 'company': ' Mindbox ', 'position': 'Москва, Белорусская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': 90000, 'finance_max': 110000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a96b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Ведущий разработчик Python / Software development / Team lead', 'href': 'https://chelyabinsk.hh.ru/vacancy/34200113?query=python', 'company': ' CATAPULTO.RU ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a96c')}
# OK
# =============================================================
# =============================================================
# {'name': 'Ведущий разработчик Python / Software development / Team lead', 'href': 'https://chelyabinsk.hh.ru/vacancy/35259844?query=python', 'company': ' CATAPULTO.RU ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a96d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior QA Automation Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35172401?query=python', 'company': ' iTechArt Group ', 'position': 'Минск, Институт Культуры', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a96e')}
# OK
# =============================================================
# =============================================================
# {'name': 'WEB разработчик, Backend', 'href': 'https://chelyabinsk.hh.ru/vacancy/35650964?query=python', 'company': 'ТОО SOMNIUM ', 'position': 'Нур-Султан', 'site': 'https://hh.ru', 'finance_min': 400000, 'finance_max': 800000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a96f')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/33738779?query=python', 'company': ' iTechArt Group ', 'position': 'Минск, Институт Культуры', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a970')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer (Mogilev)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35581311?query=python', 'company': ' iTechArt Group ', 'position': 'Могилев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a971')}
# OK
# =============================================================
# =============================================================
# {'name': 'Data Scientist', 'href': 'https://chelyabinsk.hh.ru/vacancy/35011897?query=python', 'company': ' HeadHunter::Analytics/Data Science ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a972')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661240?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Киев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a973')}
# OK
# =============================================================
# =============================================================
# {'name': 'Тестировщик / QA', 'href': 'https://chelyabinsk.hh.ru/vacancy/35571320?query=python', 'company': ' Zoon.ru ', 'position': 'Москва, Аэропорт', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a974')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661239?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a975')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик в Процессы бэк-офиса', 'href': 'https://chelyabinsk.hh.ru/vacancy/34950926?query=python', 'company': ' Яндекс ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a976')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661238?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a977')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Middle Python Developer (Mogilev)', 'href': 'https://chelyabinsk.hh.ru/vacancy/33576421?query=python', 'company': ' iTechArt Group ', 'position': 'Могилев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a978')}
# OK
# =============================================================
# =============================================================
# {'name': 'Software Test Engineer (Python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35586315?query=python', 'company': 'ООО СК хайникс мемори солюшнс Восточная Европа ', 'position': 'Минск, Немига', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a979')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661207?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97a')}
# OK
# =============================================================
# =============================================================
# {'name': 'Test Automation Engineer (Python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35164556?query=python', 'company': 'ЗАО Научсофт ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661208?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Киев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661206?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Веб-аналитик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35659622?query=python', 'company': ' 21vek.by ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97e')}
# OK
# =============================================================
# =============================================================
# {'name': 'IOS Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/32481016?query=python', 'company': ' ДомКлик ', 'position': 'Москва, Кутузовская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97f')}
# OK
# =============================================================
# =============================================================
# {'name': 'Аналитик (команда Поиска)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35121709?query=python', 'company': ' HeadHunter::Analytics/Data Science ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a980')}
# OK
# =============================================================
# =============================================================
# {'name': 'Специалист по анализу данных', 'href': 'https://chelyabinsk.hh.ru/vacancy/35613327?query=python', 'company': ' Леруа Мерлен. Центральный офис ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a981')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux / DevOps/Митино', 'href': 'https://chelyabinsk.hh.ru/vacancy/35105576?query=python', 'company': 'ООО ТЛ Групп ', 'position': 'Москва, Митино и еще 1 ', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a982')}
# OK
# =============================================================
# =============================================================
# {'name': 'Product owner (команда face recognition)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34669711?query=python', 'company': ' ЦРТ | Группа компаний ', 'position': 'Санкт-Петербург, Выборгская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a983')}
# OK
# =============================================================
# =============================================================
# {'name': 'Middle/Senior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34784844?query=python', 'company': 'ЗАО Научсофт ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a984')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Frontend Developer (JavaScript, React)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34746892?query=python', 'company': ' HeadHunter::Frontend ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': 230000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a985')}
# OK
# =============================================================
# =============================================================
# {'name': 'Teamlead команды разработки', 'href': 'https://chelyabinsk.hh.ru/vacancy/35565277?query=python', 'company': 'ТОО Коркем Телеком ', 'position': 'Нур-Султан', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a986')}
# OK
# =============================================================
# =============================================================
# {'name': 'Инженер-программист (devops)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35144040?query=python', 'company': ' А1. Информационные технологии, телеком ', 'position': 'Минск, Октябрьская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a987')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux / DevOps', 'href': 'https://chelyabinsk.hh.ru/vacancy/35612848?query=python', 'company': 'ООО ТЛ Групп ', 'position': 'Вологда', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a988')}
# OK
# =============================================================
# =============================================================
# {'name': 'Frontend-разработчик (Vue.js)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35569303?query=python', 'company': 'ООО ЦЦЭТ ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 90000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a989')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer, Roads', 'href': 'https://chelyabinsk.hh.ru/vacancy/35564440?query=python', 'company': 'ООО МэпДэйта ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98a')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35291489?query=python', 'company': ' amoCRM ', 'position': 'Москва, Таганская', 'site': 'https://hh.ru', 'finance_min': 40000, 'finance_max': 50000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a98b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35485835?query=python', 'company': ' Сбербанк для экспертов ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98c')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35522465?query=python', 'company': 'ИП Nikolay Yarovoy', 'position': 'Чехия', 'site': 'https://hh.ru', 'finance_min': 1500, 'finance_max': 3000, 'valuta': 'USD', '_id': ObjectId('5e393ccddb491d142937a98d')}
# OK
# =============================================================
# =============================================================
# {'name': 'Web Developer with Angular/Python (Berlin)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35392114?query=python', 'company': ' EdgeCase Technology ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 4200, 'finance_max': 5800, 'valuta': 'EUR', '_id': ObjectId('5e393ccddb491d142937a98e')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35568546?query=python', 'company': ' KamaGames Studio ', 'position': 'Москва, Новокузнецкая', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98f')}
# OK
# =============================================================
# =============================================================
# {'name': 'ML/DS - developer (Python/C++)', 'href': 'https://chelyabinsk.hh.ru/vacancy/32989068?query=python', 'company': ' Кадровое агентство Алексея Сухорукова ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a990')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35466343?query=python', 'company': ' Vilesse ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a991')}
# OK
# =============================================================
# =============================================================
# {'name': 'Backend Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35395690?query=python', 'company': 'ТОО AVIATA.KZ ', 'position': 'Алматы, Алмалы', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 750000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a992')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34679748?query=python', 'company': 'ООО Кловер Групп ', 'position': 'Казань', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a993')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python middle developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35286646?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 120000, 'finance_max': 160000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a994')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35631853?query=python', 'company': 'ООО Верме ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a995')}
# OK
# =============================================================
# =============================================================
# {'name': 'Backend разработчик Python / Django (Middle)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35294939?query=python', 'company': ' Zonesmart', 'position': 'Москва, Павелецкая', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a996')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист-разработчик Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35284846?query=python', 'company': 'ТОО Орион Система ', 'position': 'Алматы, Жибек Жолы', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 600000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a997')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/33157789?query=python', 'company': 'ООО Тензор ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 75000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a998')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34996134?query=python', 'company': ' Кадровик ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a999')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35295542?query=python', 'company': 'ООО Точка Зрения ', 'position': 'Ярославль', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99a')}
# OK
# =============================================================
# =============================================================
# {'name': 'Middle Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35291975?query=python', 'company': ' First_Line ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a99b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35646033?query=python', 'company': 'ООО Юкар ', 'position': 'Хабаровск', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99c')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python senior developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35287064?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99d')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35569509?query=python', 'company': ' zClick.pro ', 'position': 'Москва, Молодежная', 'site': 'https://hh.ru', 'finance_min': 160000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99e')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35572180?query=python', 'company': ' AppQuantum', 'position': 'Москва, Автозаводская', 'site': 'https://hh.ru', 'finance_min': 170000, 'finance_max': 230000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99f')}
# OK
# =============================================================
# =============================================================
# {'name': 'Web-разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35646714?query=python', 'company': ' Carbon Soft ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 20000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a0')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик на Python (Senior), Москва', 'href': 'https://chelyabinsk.hh.ru/vacancy/35080649?query=python', 'company': ' DriverPack Solution ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 300000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a1')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python (Django) developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35245102?query=python', 'company': ' evrone.ru ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 180000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a2')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/33289186?query=python', 'company': 'ИП Sibdev ', 'position': 'Красноярск', 'site': 'https://hh.ru', 'finance_min': 32000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a3')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python/Стажер-программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35273456?query=python', 'company': ' IConsult ', 'position': 'Долгопрудный', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a4')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35246667?query=python', 'company': 'ООО Единая Информационная Система ЖКХ ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9a5')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35359838?query=python', 'company': ' IVIDEON ', 'position': 'Рязань', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a6')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35143709?query=python', 'company': ' Fijowave Ltd ', 'position': 'Челябинск', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a7')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35241081?query=python', 'company': ' B2Broker ', 'position': 'Санкт-Петербург, Петроградская', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a8')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python (ГИС)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35269923?query=python', 'company': ' РеИнформ Инт. ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a9')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Web Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34064729?query=python', 'company': ' EY ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9aa')}
# OK
# =============================================================
# =============================================================
# {'name': 'Младший программист на Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35611994?query=python', 'company': 'ООО РиТон ', 'position': 'Санкт-Петербург, Электросила', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ab')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35148468?query=python', 'company': 'ООО Саратовский резервуарный завод ', 'position': 'Саратов', 'site': 'https://hh.ru', 'finance_min': 96000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ac')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34274386?query=python', 'company': 'ПАО МегаФон, IT ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ad')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34767945?query=python', 'company': ' Hype Auditor ', 'position': 'Санкт-Петербург, Горьковская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ae')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer (Django)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35265218?query=python', 'company': ' Акрибия ', 'position': 'Санкт-Петербург, Площадь Ленина', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9af')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34612988?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Ростов-на-Дону', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b0')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior ML Engineer / Data scientist', 'href': 'https://chelyabinsk.hh.ru/vacancy/35459810?query=python', 'company': 'ООО Когнитив Роботикс ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b1')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35240421?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35348633?query=python', 'company': 'АО НейроТренд ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b3')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35240438?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Волгоград', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b4')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35276223?query=python', 'company': 'ИП Черкасов Константин Юрьевич ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 90000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b5')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python middle developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35264565?query=python', 'company': ' БАРБАКАН ', 'position': 'Москва, Маяковская', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b6')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35620095?query=python', 'company': ' RU-CERT ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b7')}
# OK
# =============================================================
# =============================================================
# {'name': 'Team lead Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35287422?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b8')}
# OK
# =============================================================
# =============================================================
# {'name': 'Middle Python Developer/Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35228732?query=python', 'company': 'ЗАО КАДФЕМ Си-Ай-Эс ', 'position': 'Санкт-Петербург, Площадь Ленина', 'site': 'https://hh.ru', 'finance_min': 85000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b9')}
# OK
# =============================================================
# =============================================================
# {'name': 'DevOps/разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35618972?query=python', 'company': ' Alertgroup ', 'position': 'Санкт-Петербург, Балтийская', 'site': 'https://hh.ru', 'finance_min': 75000, 'finance_max': 140000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ba')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Back-end Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35567208?query=python', 'company': ' Фингерз Медиа ', 'position': 'Минск, Московская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9bb')}
# OK
# =============================================================
# =============================================================
# {'name': 'Бэкенд-разработчик на Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35564589?query=python', 'company': ' Канобу ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 70000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bc')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35638194?query=python', 'company': ' BORK ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 130000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bd')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35453431?query=python', 'company': ' Matller ', 'position': 'Нижний Новгород, Горьковская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9be')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34200903?query=python', 'company': 'АО НИИ МАСШТАБ ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': 70000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bf')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/33610810?query=python', 'company': ' Вяртсиля, Центр цифровых технологий ', 'position': 'Санкт-Петербург, Василеостровская и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c0')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35613216?query=python', 'company': 'ООО Телепорт ', 'position': 'Санкт-Петербург, Кировский завод', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 130000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c1')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Python Developer (to Riga)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35173848?query=python', 'company': ' Betby ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 3000, 'finance_max': 4500, 'valuta': 'EUR', '_id': ObjectId('5e393ccddb491d142937a9c2')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python (Junior)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34409863?query=python', 'company': 'ООО Открытые Бизнес Технологии ', 'position': 'Волгоград', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c3')}
# OK
# =============================================================
# =============================================================
# {'name': 'Младший Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34784886?query=python', 'company': ' Инфосистемы Джет ', 'position': 'Нижний Новгород', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c4')}
# OK
# =============================================================
# =============================================================
# {'name': 'Big Data/Machine Learning Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35560808?query=python', 'company': ' SkyTech Solutions ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c5')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35568633?query=python', 'company': 'ООО Флайдата ', 'position': 'Москва, Багратионовская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c6')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35506627?query=python', 'company': 'АО СБК ', 'position': 'Москва, Савеловская', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': 160000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c7')}
# OK
# =============================================================
# =============================================================
# {'name': 'Трейдер', 'href': 'https://chelyabinsk.hh.ru/vacancy/35627778?query=python', 'company': 'АО Спутник-Управление капиталом, УК ', 'position': 'Москва, Павелецкая и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c8')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35507770?query=python', 'company': 'ООО КОМТЕК ', 'position': 'Уфа', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 60000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c9')}
# OK
# =============================================================
# =============================================================
# {'name': 'Senior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35151283?query=python', 'company': ' Improvado ', 'position': 'Москва, Павелецкая', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ca')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python (Middle)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35640267?query=python', 'company': ' Carbon Soft ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cb')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Back-end разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35563158?query=python', 'company': ' AERODISK ', 'position': 'Москва, Калужская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9cc')}
# OK
# =============================================================
# =============================================================
# {'name': 'Ведущий программист Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35636391?query=python', 'company': 'ООО ДЖАСТ ВОРК ', 'position': 'Казань', 'site': 'https://hh.ru', 'finance_min': 130000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cd')}
# OK
# =============================================================
# =============================================================
# {'name': 'Junior Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35259045?query=python', 'company': ' NAUMEN ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ce')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35659124?query=python', 'company': 'ООО Кубэкс Рус ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cf')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик (updated)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35353435?query=python', 'company': ' РокетМама ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d0')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python-програміст', 'href': 'https://chelyabinsk.hh.ru/vacancy/35339790?query=python', 'company': ' Группа компаний Танграм ', 'position': 'Полтава', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d1')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python-програміст', 'href': 'https://chelyabinsk.hh.ru/vacancy/35339725?query=python', 'company': ' Группа компаний Танграм ', 'position': 'Николаев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35656765?query=python', 'company': ' Лаборатория цифровых прав ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d3')}
# OK
# =============================================================
# =============================================================
# {'name': 'Старший разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35447201?query=python', 'company': 'ООО Мандарин ', 'position': 'Москва, Водный стадион', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d4')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35422845?query=python', 'company': ' SEMrush ', 'position': 'Санкт-Петербург, Московские ворота', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d5')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35075027?query=python', 'company': ' NPM ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 90000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d6')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35031375?query=python', 'company': ' START.RU ', 'position': 'Москва, Спортивная и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d7')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35350974?query=python', 'company': ' ИнПлат ', 'position': 'Москва, Менделеевская и еще 2 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d8')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35205220?query=python', 'company': ' MaxiBooking ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 120000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d9')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Python backend', 'href': 'https://chelyabinsk.hh.ru/vacancy/33386841?query=python', 'company': ' Офисный Мир КМ ', 'position': 'Ростов-на-Дону', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 140000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9da')}
# OK
# =============================================================
# =============================================================
# {'name': 'Python Developer (Big Data)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35219354?query=python', 'company': ' Группа компаний eLama ', 'position': 'Санкт-Петербург, Московские ворота', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9db')}
# OK
# =============================================================
# ...
# =============================================================
# {'name': 'Разработчик Java', 'href': 'https://www.superjob.ru/vakansii/razrabotchik-java-33339694.html', 'company': 'Дом.ru', 'position': 'вчера • Пермь', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b168')}
# OK
# =============================================================
# =============================================================
# {'name': 'Тестировщик программного обеспечения', 'href': 'https://www.superjob.ru/vakansii/testirovschik-programmnogo-obespecheniya-32202847.html', 'company': 'Правительство Москвы', 'position': 'вчера • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b169')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист баз данных', 'href': 'https://www.superjob.ru/vakansii/programmist-baz-dannyh-33349779.html', 'company': 'Sterling', 'position': 'вчера • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16a')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-30612921.html', 'company': 'Филиал ФКУ "Налог-Сервис"', 'position': 'вчера • Волгоград', 'site': 'https://www.superjob.ru', 'finance_min': 25000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Старший back-end разработчик', 'href': 'https://www.superjob.ru/vakansii/starshij-back-end-razrabotchik-32566666.html', 'company': 'ВИЗАВИ Консалт', 'position': 'вчера • Вологда', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16c')}
# OK
# =============================================================
# =============================================================
# {'name': 'Data Scientist', 'href': 'https://www.superjob.ru/vakansii/data-scientist-33248352.html', 'company': 'ВИЗАВИ Консалт', 'position': 'вчера • Вологда', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b16d')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-32075249.html', 'company': 'ГАРАНТ', 'position': 'вчера • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': 35000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16e')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-33463087.html', 'company': 'Э-Студио', 'position': 'вчера • Йошкар-Ола', 'site': 'https://www.superjob.ru', 'finance_min': 30000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16f')}
# OK
# =============================================================
# =============================================================
# {'name': 'Младший системный администратор Linux', 'href': 'https://www.superjob.ru/vakansii/mladshij-sistemnyj-administrator-linux-32235514.html', 'company': 'Самсон-опт', 'position': 'вчера • Воронеж', 'site': 'https://www.superjob.ru', 'finance_min': 54000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b170')}
# OK
# =============================================================
# =============================================================
# {'name': 'Ведущий эксперт по СУПП', 'href': 'https://www.superjob.ru/vakansii/veduschij-ekspert-po-supp-32618908.html', 'company': '«Т Плюс»', 'position': 'вчера • Екатеринбург', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b171')}
# OK
# =============================================================
# =============================================================
# {'name': 'Руководитель группы тестирования ПО', 'href': 'https://www.superjob.ru/vakansii/rukovoditel-gruppy-testirovaniya-po-33397052.html', 'company': 'С-Терра СиЭсПи', 'position': '2 февраля • Москва,Верхние Лихоборы', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b172')}
# OK
# =============================================================
# =============================================================
# {'name': 'Разработчик Delphi', 'href': 'https://www.superjob.ru/vakansii/razrabotchik-delphi-30126438.html', 'company': 'НПП "Энерготехника"', 'position': '2 февраля • Пенза', 'site': 'https://www.superjob.ru', 'finance_min': 45000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b173')}
# OK
# =============================================================
# =============================================================
# {'name': 'QA engineer (Тестировщик)', 'href': 'https://www.superjob.ru/vakansii/qa-engineer-33148675.html', 'company': 'Фабрикант', 'position': '2 февраля • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b174')}
# OK
# =============================================================
# =============================================================
# {'name': 'Инженер, техник', 'href': 'https://www.superjob.ru/vakansii/inzhener-33089687.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 35000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b175')}
# OK
# =============================================================
# =============================================================
# {'name': 'Инженер (программирование)', 'href': 'https://www.superjob.ru/vakansii/inzhener-33089911.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b176')}
# OK
# =============================================================
# =============================================================
# {'name': 'Инженер-программист', 'href': 'https://www.superjob.ru/vakansii/inzhener-programmist-33092773.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b177')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-33159142.html', 'company': 'Трансойл', 'position': '1 февраля • Санкт-Петербург,Площадь Ленина, Горьковская', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b178')}
# OK
# =============================================================
# =============================================================
# {'name': 'Web-разработчик React', 'href': 'https://www.superjob.ru/vakansii/web-razrabotchik-react-32675674.html', 'company': 'КРИТ', 'position': '1 февраля • Ижевск', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b179')}
# OK
# =============================================================
# =============================================================
# {'name': 'Администратор Linux (релокейт в Москву)', 'href': 'https://www.superjob.ru/vakansii/administrator-linux-33385460.html', 'company': 'Global Personal', 'position': '1 февраля • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': 120000, 'finance_max': 160000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17a')}
# OK
# =============================================================
# =============================================================
# {'name': 'Специалист по внедрению и сопровождению информационных систем', 'href': 'https://www.superjob.ru/vakansii/specialist-po-vnedreniyu-i-soprovozhdeniyu-informacionnyh-sistem-33358612.html', 'company': None, 'position': None, 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b17b')}
# OK
# =============================================================
# =============================================================
# {'name': 'Преподаватель программирования и информатики', 'href': 'https://www.superjob.ru/vakansii/prepodavatel-programmirovaniya-i-informatiki-33364026.html', 'company': 'Волгоградский социально-педагогический колледж', 'position': '31 января • Волгоград', 'site': 'https://www.superjob.ru', 'finance_min': 18000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17c')}
# OK
# =============================================================
# =============================================================
# {'name': 'Специалист по анализу больших данных', 'href': 'https://www.superjob.ru/vakansii/specialist-po-analizu-bolshih-dannyh-33450384.html', 'company': 'ГКУ ТО Центр информационных технологий Тюменской области', 'position': '31 января • Тюмень', 'site': 'https://www.superjob.ru', 'finance_min': 55000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17d')}
# OK
# =============================================================
# =============================================================
# {'name': 'Главный программист', 'href': 'https://www.superjob.ru/vakansii/glavnyj-programmist-33450373.html', 'company': 'ГКУ ТО Центр информационных технологий Тюменской области', 'position': '31 января • Тюмень', 'site': 'https://www.superjob.ru', 'finance_min': 55000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17e')}
# OK
# =============================================================
# =============================================================
# {'name': 'Аналитик (отчетность)', 'href': 'https://www.superjob.ru/vakansii/analitik-33308640.html', 'company': 'ФГБУ ВПО «Российский государственный социальный университет»', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17f')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный аналитик', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-analitik-33308623.html', 'company': 'ФГБУ ВПО «Российский государственный социальный университет»', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b180')}
# OK
# =============================================================
# =============================================================
# {'name': 'Quantitative Researcher / Quant Analyst', 'href': 'https://www.superjob.ru/vakansii/quantitative-researcher-33371735.html', 'company': 'HBDC', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b181')}
# OK
# =============================================================
# =============================================================
# {'name': 'Специалист технического отдела', 'href': 'https://www.superjob.ru/vakansii/specialist-tehnicheskogo-otdela-33408340.html', 'company': 'Траектория', 'position': '30 января • Санкт-Петербург,Лесная, Площадь Мужества\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': 45000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b182')}
# OK
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux (Zabbix)', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-linux-32992548.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '30 января • Москва,Сходненская, Волоколамская\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': 70000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b183')}
# OK
# =============================================================
# =============================================================
# {'name': 'Администратор баз данных PostgreSQL', 'href': 'https://www.superjob.ru/vakansii/administrator-baz-dannyh-postgresql-32992512.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '29 января • Москва,Сходненская, Волоколамская\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': 150000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b184')}
# OK
# =============================================================
# =============================================================
# {'name': 'Начальник отдела информационных технологий', 'href': 'https://www.superjob.ru/vakansii/nachalnik-otdela-informacionnyh-tehnologij-33364015.html', 'company': 'Башкортостанстат', 'position': '29 января • Уфа', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': 50000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b185')}
# OK
# =============================================================
# =============================================================
# {'name': 'Программист', 'href': 'https://www.superjob.ru/vakansii/programmist-33437653.html', 'company': 'Центр стратегического планирования Минздрава РФ', 'position': '29 января • Москва,Щукинская', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b186')}
# OK
# =============================================================
# =============================================================
# {'name': 'Ведущий Web-разработчик PHP, JS (full stack)', 'href': 'https://www.superjob.ru/vakansii/veduschij-web-razrabotchik-php-33399983.html', 'company': 'Север Авто М', 'position': '29 января • Москва,Шоссе Энтузиастов, Чкаловская', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b187')}
# OK
# =============================================================
# =============================================================
# {'name': 'Доцент', 'href': 'https://www.superjob.ru/vakansii/docent-33361314.html', 'company': 'ФГБОУ ВО СПбГАСУ', 'position': '28 января • Санкт-Петербург,Технологический институт I, Технологический институт II', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': 70000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b188')}
# OK
# =============================================================
# =============================================================
# {'name': 'Тестировщик (автоматизатор)', 'href': 'https://www.superjob.ru/vakansii/testirovschik-33359565.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '28 января • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b189')}
# OK
# =============================================================

# %%
data = reade_DataBase(vacancy)
print(len(data))
# Out:
# 1868

# %%
save_one_data_DataBase(vacancy, result)
# Out:
# =============================================================
# {'name': 'Junior data scientist (ML разработчик, python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35660654?query=python', 'company': ' Mindbox ', 'position': 'Москва, Белорусская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': 90000, 'finance_max': 110000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a96b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Ведущий разработчик Python / Software development / Team lead', 'href': 'https://chelyabinsk.hh.ru/vacancy/34200113?query=python', 'company': ' CATAPULTO.RU ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a96c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Ведущий разработчик Python / Software development / Team lead', 'href': 'https://chelyabinsk.hh.ru/vacancy/35259844?query=python', 'company': ' CATAPULTO.RU ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a96d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior QA Automation Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35172401?query=python', 'company': ' iTechArt Group ', 'position': 'Минск, Институт Культуры', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a96e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'WEB разработчик, Backend', 'href': 'https://chelyabinsk.hh.ru/vacancy/35650964?query=python', 'company': 'ТОО SOMNIUM ', 'position': 'Нур-Султан', 'site': 'https://hh.ru', 'finance_min': 400000, 'finance_max': 800000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a96f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/33738779?query=python', 'company': ' iTechArt Group ', 'position': 'Минск, Институт Культуры', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a970')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer (Mogilev)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35581311?query=python', 'company': ' iTechArt Group ', 'position': 'Могилев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a971')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Data Scientist', 'href': 'https://chelyabinsk.hh.ru/vacancy/35011897?query=python', 'company': ' HeadHunter::Analytics/Data Science ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a972')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661240?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Киев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a973')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Тестировщик / QA', 'href': 'https://chelyabinsk.hh.ru/vacancy/35571320?query=python', 'company': ' Zoon.ru ', 'position': 'Москва, Аэропорт', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a974')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661239?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a975')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик в Процессы бэк-офиса', 'href': 'https://chelyabinsk.hh.ru/vacancy/34950926?query=python', 'company': ' Яндекс ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a976')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Analyst', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661238?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a977')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Middle Python Developer (Mogilev)', 'href': 'https://chelyabinsk.hh.ru/vacancy/33576421?query=python', 'company': ' iTechArt Group ', 'position': 'Могилев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a978')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Software Test Engineer (Python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35586315?query=python', 'company': 'ООО СК хайникс мемори солюшнс Восточная Европа ', 'position': 'Минск, Немига', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a979')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661207?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97a')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Test Automation Engineer (Python)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35164556?query=python', 'company': 'ЗАО Научсофт ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661208?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Киев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35661206?query=python', 'company': ' Ruby Labs Ltd ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Веб-аналитик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35659622?query=python', 'company': ' 21vek.by ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'IOS Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/32481016?query=python', 'company': ' ДомКлик ', 'position': 'Москва, Кутузовская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a97f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Аналитик (команда Поиска)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35121709?query=python', 'company': ' HeadHunter::Analytics/Data Science ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a980')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Специалист по анализу данных', 'href': 'https://chelyabinsk.hh.ru/vacancy/35613327?query=python', 'company': ' Леруа Мерлен. Центральный офис ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a981')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux / DevOps/Митино', 'href': 'https://chelyabinsk.hh.ru/vacancy/35105576?query=python', 'company': 'ООО ТЛ Групп ', 'position': 'Москва, Митино и еще 1 ', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a982')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Product owner (команда face recognition)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34669711?query=python', 'company': ' ЦРТ | Группа компаний ', 'position': 'Санкт-Петербург, Выборгская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a983')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Middle/Senior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34784844?query=python', 'company': 'ЗАО Научсофт ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a984')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Frontend Developer (JavaScript, React)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34746892?query=python', 'company': ' HeadHunter::Frontend ', 'position': 'Москва, Алексеевская', 'site': 'https://hh.ru', 'finance_min': 230000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a985')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Teamlead команды разработки', 'href': 'https://chelyabinsk.hh.ru/vacancy/35565277?query=python', 'company': 'ТОО Коркем Телеком ', 'position': 'Нур-Султан', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a986')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Инженер-программист (devops)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35144040?query=python', 'company': ' А1. Информационные технологии, телеком ', 'position': 'Минск, Октябрьская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a987')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux / DevOps', 'href': 'https://chelyabinsk.hh.ru/vacancy/35612848?query=python', 'company': 'ООО ТЛ Групп ', 'position': 'Вологда', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a988')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Frontend-разработчик (Vue.js)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35569303?query=python', 'company': 'ООО ЦЦЭТ ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 90000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a989')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Data Engineer, Roads', 'href': 'https://chelyabinsk.hh.ru/vacancy/35564440?query=python', 'company': 'ООО МэпДэйта ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98a')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35291489?query=python', 'company': ' amoCRM ', 'position': 'Москва, Таганская', 'site': 'https://hh.ru', 'finance_min': 40000, 'finance_max': 50000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a98b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35485835?query=python', 'company': ' Сбербанк для экспертов ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35522465?query=python', 'company': 'ИП Nikolay Yarovoy', 'position': 'Чехия', 'site': 'https://hh.ru', 'finance_min': 1500, 'finance_max': 3000, 'valuta': 'USD', '_id': ObjectId('5e393ccddb491d142937a98d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Web Developer with Angular/Python (Berlin)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35392114?query=python', 'company': ' EdgeCase Technology ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 4200, 'finance_max': 5800, 'valuta': 'EUR', '_id': ObjectId('5e393ccddb491d142937a98e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35568546?query=python', 'company': ' KamaGames Studio ', 'position': 'Москва, Новокузнецкая', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a98f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'ML/DS - developer (Python/C++)', 'href': 'https://chelyabinsk.hh.ru/vacancy/32989068?query=python', 'company': ' Кадровое агентство Алексея Сухорукова ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a990')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35466343?query=python', 'company': ' Vilesse ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a991')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Backend Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35395690?query=python', 'company': 'ТОО AVIATA.KZ ', 'position': 'Алматы, Алмалы', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 750000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a992')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34679748?query=python', 'company': 'ООО Кловер Групп ', 'position': 'Казань', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a993')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python middle developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35286646?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 120000, 'finance_max': 160000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a994')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35631853?query=python', 'company': 'ООО Верме ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a995')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Backend разработчик Python / Django (Middle)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35294939?query=python', 'company': ' Zonesmart', 'position': 'Москва, Павелецкая', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a996')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист-разработчик Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35284846?query=python', 'company': 'ТОО Орион Система ', 'position': 'Алматы, Жибек Жолы', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 600000, 'valuta': 'KZT', '_id': ObjectId('5e393ccddb491d142937a997')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/33157789?query=python', 'company': 'ООО Тензор ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 75000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a998')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34996134?query=python', 'company': ' Кадровик ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a999')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35295542?query=python', 'company': 'ООО Точка Зрения ', 'position': 'Ярославль', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99a')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Middle Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35291975?query=python', 'company': ' First_Line ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a99b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35646033?query=python', 'company': 'ООО Юкар ', 'position': 'Хабаровск', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python senior developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35287064?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35569509?query=python', 'company': ' zClick.pro ', 'position': 'Москва, Молодежная', 'site': 'https://hh.ru', 'finance_min': 160000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35572180?query=python', 'company': ' AppQuantum', 'position': 'Москва, Автозаводская', 'site': 'https://hh.ru', 'finance_min': 170000, 'finance_max': 230000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a99f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Web-разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35646714?query=python', 'company': ' Carbon Soft ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 20000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a0')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик на Python (Senior), Москва', 'href': 'https://chelyabinsk.hh.ru/vacancy/35080649?query=python', 'company': ' DriverPack Solution ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 300000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a1')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python (Django) developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35245102?query=python', 'company': ' evrone.ru ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 180000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/33289186?query=python', 'company': 'ИП Sibdev ', 'position': 'Красноярск', 'site': 'https://hh.ru', 'finance_min': 32000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a3')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python/Стажер-программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35273456?query=python', 'company': ' IConsult ', 'position': 'Долгопрудный', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a4')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35246667?query=python', 'company': 'ООО Единая Информационная Система ЖКХ ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9a5')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35359838?query=python', 'company': ' IVIDEON ', 'position': 'Рязань', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a6')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35143709?query=python', 'company': ' Fijowave Ltd ', 'position': 'Челябинск', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a7')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35241081?query=python', 'company': ' B2Broker ', 'position': 'Санкт-Петербург, Петроградская', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a8')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python (ГИС)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35269923?query=python', 'company': ' РеИнформ Инт. ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9a9')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Web Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34064729?query=python', 'company': ' EY ', 'position': 'Минск', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9aa')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Младший программист на Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35611994?query=python', 'company': 'ООО РиТон ', 'position': 'Санкт-Петербург, Электросила', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ab')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35148468?query=python', 'company': 'ООО Саратовский резервуарный завод ', 'position': 'Саратов', 'site': 'https://hh.ru', 'finance_min': 96000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ac')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34274386?query=python', 'company': 'ПАО МегаФон, IT ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ad')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34767945?query=python', 'company': ' Hype Auditor ', 'position': 'Санкт-Петербург, Горьковская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ae')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python Developer (Django)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35265218?query=python', 'company': ' Акрибия ', 'position': 'Санкт-Петербург, Площадь Ленина', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9af')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/34612988?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Ростов-на-Дону', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b0')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior ML Engineer / Data scientist', 'href': 'https://chelyabinsk.hh.ru/vacancy/35459810?query=python', 'company': 'ООО Когнитив Роботикс ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b1')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35240421?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35348633?query=python', 'company': 'АО НейроТренд ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b3')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35240438?query=python', 'company': 'ООО ЛАЙТ МЭП ', 'position': 'Волгоград', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9b4')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35276223?query=python', 'company': 'ИП Черкасов Константин Юрьевич ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 90000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b5')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python middle developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35264565?query=python', 'company': ' БАРБАКАН ', 'position': 'Москва, Маяковская', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b6')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35620095?query=python', 'company': ' RU-CERT ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 150000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b7')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Team lead Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35287422?query=python', 'company': ' BestDoctor ', 'position': 'Москва, Парк Победы и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b8')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Middle Python Developer/Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35228732?query=python', 'company': 'ЗАО КАДФЕМ Си-Ай-Эс ', 'position': 'Санкт-Петербург, Площадь Ленина', 'site': 'https://hh.ru', 'finance_min': 85000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9b9')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'DevOps/разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35618972?query=python', 'company': ' Alertgroup ', 'position': 'Санкт-Петербург, Балтийская', 'site': 'https://hh.ru', 'finance_min': 75000, 'finance_max': 140000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9ba')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Back-end Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35567208?query=python', 'company': ' Фингерз Медиа ', 'position': 'Минск, Московская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9bb')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Бэкенд-разработчик на Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35564589?query=python', 'company': ' Канобу ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 70000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bc')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35638194?query=python', 'company': ' BORK ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 130000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bd')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35453431?query=python', 'company': ' Matller ', 'position': 'Нижний Новгород, Горьковская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9be')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34200903?query=python', 'company': 'АО НИИ МАСШТАБ ', 'position': 'Санкт-Петербург', 'site': 'https://hh.ru', 'finance_min': 70000, 'finance_max': 100000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9bf')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/33610810?query=python', 'company': ' Вяртсиля, Центр цифровых технологий ', 'position': 'Санкт-Петербург, Василеостровская и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 60000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c0')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35613216?query=python', 'company': 'ООО Телепорт ', 'position': 'Санкт-Петербург, Кировский завод', 'site': 'https://hh.ru', 'finance_min': 100000, 'finance_max': 130000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c1')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Python Developer (to Riga)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35173848?query=python', 'company': ' Betby ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 3000, 'finance_max': 4500, 'valuta': 'EUR', '_id': ObjectId('5e393ccddb491d142937a9c2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python (Junior)', 'href': 'https://chelyabinsk.hh.ru/vacancy/34409863?query=python', 'company': 'ООО Открытые Бизнес Технологии ', 'position': 'Волгоград', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c3')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Младший Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/34784886?query=python', 'company': ' Инфосистемы Джет ', 'position': 'Нижний Новгород', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c4')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Big Data/Machine Learning Engineer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35560808?query=python', 'company': ' SkyTech Solutions ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': 180000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c5')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35568633?query=python', 'company': 'ООО Флайдата ', 'position': 'Москва, Багратионовская и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9c6')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35506627?query=python', 'company': 'АО СБК ', 'position': 'Москва, Савеловская', 'site': 'https://hh.ru', 'finance_min': 140000, 'finance_max': 160000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c7')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Трейдер', 'href': 'https://chelyabinsk.hh.ru/vacancy/35627778?query=python', 'company': 'АО Спутник-Управление капиталом, УК ', 'position': 'Москва, Павелецкая и еще 2 ', 'site': 'https://hh.ru', 'finance_min': 150000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c8')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35507770?query=python', 'company': 'ООО КОМТЕК ', 'position': 'Уфа', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': 60000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9c9')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Senior Python developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35151283?query=python', 'company': ' Improvado ', 'position': 'Москва, Павелецкая', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ca')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Python (Middle)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35640267?query=python', 'company': ' Carbon Soft ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': 50000, 'finance_max': 120000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cb')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Back-end разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35563158?query=python', 'company': ' AERODISK ', 'position': 'Москва, Калужская', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9cc')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Ведущий программист Python/Django', 'href': 'https://chelyabinsk.hh.ru/vacancy/35636391?query=python', 'company': 'ООО ДЖАСТ ВОРК ', 'position': 'Казань', 'site': 'https://hh.ru', 'finance_min': 130000, 'finance_max': 200000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cd')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Junior Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35259045?query=python', 'company': ' NAUMEN ', 'position': 'Екатеринбург', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9ce')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35659124?query=python', 'company': 'ООО Кубэкс Рус ', 'position': 'Краснодар', 'site': 'https://hh.ru', 'finance_min': 80000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9cf')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик (updated)', 'href': 'https://chelyabinsk.hh.ru/vacancy/35353435?query=python', 'company': ' РокетМама ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d0')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-програміст', 'href': 'https://chelyabinsk.hh.ru/vacancy/35339790?query=python', 'company': ' Группа компаний Танграм ', 'position': 'Полтава', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d1')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-програміст', 'href': 'https://chelyabinsk.hh.ru/vacancy/35339725?query=python', 'company': ' Группа компаний Танграм ', 'position': 'Николаев', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d2')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python-разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35656765?query=python', 'company': ' Лаборатория цифровых прав ', 'position': 'Москва', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d3')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Старший разработчик Python', 'href': 'https://chelyabinsk.hh.ru/vacancy/35447201?query=python', 'company': 'ООО Мандарин ', 'position': 'Москва, Водный стадион', 'site': 'https://hh.ru', 'finance_min': 200000, 'finance_max': 250000, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d4')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python Developer', 'href': 'https://chelyabinsk.hh.ru/vacancy/35422845?query=python', 'company': ' SEMrush ', 'position': 'Санкт-Петербург, Московские ворота', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d5')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35075027?query=python', 'company': ' NPM ', 'position': 'Новосибирск', 'site': 'https://hh.ru', 'finance_min': 90000, 'finance_max': None, 'valuta': 'руб.', '_id': ObjectId('5e393ccddb491d142937a9d6')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Python разработчик', 'href': 'https://chelyabinsk.hh.ru/vacancy/35031375?query=python', 'company': ' START.RU ', 'position': 'Москва, Спортивная и еще 1 ', 'site': 'https://hh.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccddb491d142937a9d7')}
# ERROR, duplicate
# =============================================================
# =============================================================
# ...
# {'name': 'Тестировщик программного обеспечения', 'href': 'https://www.superjob.ru/vakansii/testirovschik-programmnogo-obespecheniya-32202847.html', 'company': 'Правительство Москвы', 'position': 'вчера • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b169')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист баз данных', 'href': 'https://www.superjob.ru/vakansii/programmist-baz-dannyh-33349779.html', 'company': 'Sterling', 'position': 'вчера • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 100000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16a')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-30612921.html', 'company': 'Филиал ФКУ "Налог-Сервис"', 'position': 'вчера • Волгоград', 'site': 'https://www.superjob.ru', 'finance_min': 25000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Старший back-end разработчик', 'href': 'https://www.superjob.ru/vakansii/starshij-back-end-razrabotchik-32566666.html', 'company': 'ВИЗАВИ Консалт', 'position': 'вчера • Вологда', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Data Scientist', 'href': 'https://www.superjob.ru/vakansii/data-scientist-33248352.html', 'company': 'ВИЗАВИ Консалт', 'position': 'вчера • Вологда', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b16d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-32075249.html', 'company': 'ГАРАНТ', 'position': 'вчера • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': 35000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-33463087.html', 'company': 'Э-Студио', 'position': 'вчера • Йошкар-Ола', 'site': 'https://www.superjob.ru', 'finance_min': 30000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b16f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Младший системный администратор Linux', 'href': 'https://www.superjob.ru/vakansii/mladshij-sistemnyj-administrator-linux-32235514.html', 'company': 'Самсон-опт', 'position': 'вчера • Воронеж', 'site': 'https://www.superjob.ru', 'finance_min': 54000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b170')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Ведущий эксперт по СУПП', 'href': 'https://www.superjob.ru/vakansii/veduschij-ekspert-po-supp-32618908.html', 'company': '«Т Плюс»', 'position': 'вчера • Екатеринбург', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b171')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Руководитель группы тестирования ПО', 'href': 'https://www.superjob.ru/vakansii/rukovoditel-gruppy-testirovaniya-po-33397052.html', 'company': 'С-Терра СиЭсПи', 'position': '2 февраля • Москва,Верхние Лихоборы', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b172')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Разработчик Delphi', 'href': 'https://www.superjob.ru/vakansii/razrabotchik-delphi-30126438.html', 'company': 'НПП "Энерготехника"', 'position': '2 февраля • Пенза', 'site': 'https://www.superjob.ru', 'finance_min': 45000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b173')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'QA engineer (Тестировщик)', 'href': 'https://www.superjob.ru/vakansii/qa-engineer-33148675.html', 'company': 'Фабрикант', 'position': '2 февраля • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b174')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Инженер, техник', 'href': 'https://www.superjob.ru/vakansii/inzhener-33089687.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 35000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b175')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Инженер (программирование)', 'href': 'https://www.superjob.ru/vakansii/inzhener-33089911.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b176')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Инженер-программист', 'href': 'https://www.superjob.ru/vakansii/inzhener-programmist-33092773.html', 'company': 'ВНИИФТРИ', 'position': '2 февраля • Зеленоград', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b177')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-33159142.html', 'company': 'Трансойл', 'position': '1 февраля • Санкт-Петербург,Площадь Ленина, Горьковская', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b178')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Web-разработчик React', 'href': 'https://www.superjob.ru/vakansii/web-razrabotchik-react-32675674.html', 'company': 'КРИТ', 'position': '1 февраля • Ижевск', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b179')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Администратор Linux (релокейт в Москву)', 'href': 'https://www.superjob.ru/vakansii/administrator-linux-33385460.html', 'company': 'Global Personal', 'position': '1 февраля • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': 120000, 'finance_max': 160000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17a')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Специалист по внедрению и сопровождению информационных систем', 'href': 'https://www.superjob.ru/vakansii/specialist-po-vnedreniyu-i-soprovozhdeniyu-informacionnyh-sistem-33358612.html', 'company': None, 'position': None, 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b17b')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Преподаватель программирования и информатики', 'href': 'https://www.superjob.ru/vakansii/prepodavatel-programmirovaniya-i-informatiki-33364026.html', 'company': 'Волгоградский социально-педагогический колледж', 'position': '31 января • Волгоград', 'site': 'https://www.superjob.ru', 'finance_min': 18000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17c')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Специалист по анализу больших данных', 'href': 'https://www.superjob.ru/vakansii/specialist-po-analizu-bolshih-dannyh-33450384.html', 'company': 'ГКУ ТО Центр информационных технологий Тюменской области', 'position': '31 января • Тюмень', 'site': 'https://www.superjob.ru', 'finance_min': 55000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17d')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Главный программист', 'href': 'https://www.superjob.ru/vakansii/glavnyj-programmist-33450373.html', 'company': 'ГКУ ТО Центр информационных технологий Тюменской области', 'position': '31 января • Тюмень', 'site': 'https://www.superjob.ru', 'finance_min': 55000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17e')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Аналитик (отчетность)', 'href': 'https://www.superjob.ru/vakansii/analitik-33308640.html', 'company': 'ФГБУ ВПО «Российский государственный социальный университет»', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b17f')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный аналитик', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-analitik-33308623.html', 'company': 'ФГБУ ВПО «Российский государственный социальный университет»', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b180')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Quantitative Researcher / Quant Analyst', 'href': 'https://www.superjob.ru/vakansii/quantitative-researcher-33371735.html', 'company': 'HBDC', 'position': '30 января • Москва', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': None, 'valuta': None, '_id': ObjectId('5e393ccedb491d142937b181')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Специалист технического отдела', 'href': 'https://www.superjob.ru/vakansii/specialist-tehnicheskogo-otdela-33408340.html', 'company': 'Траектория', 'position': '30 января • Санкт-Петербург,Лесная, Площадь Мужества\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': 45000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b182')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Системный администратор Linux (Zabbix)', 'href': 'https://www.superjob.ru/vakansii/sistemnyj-administrator-linux-32992548.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '30 января • Москва,Сходненская, Волоколамская\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': 70000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b183')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Администратор баз данных PostgreSQL', 'href': 'https://www.superjob.ru/vakansii/administrator-baz-dannyh-postgresql-32992512.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '29 января • Москва,Сходненская, Волоколамская\xa0и ещё 1 станция', 'site': 'https://www.superjob.ru', 'finance_min': None, 'finance_max': 150000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b184')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Начальник отдела информационных технологий', 'href': 'https://www.superjob.ru/vakansii/nachalnik-otdela-informacionnyh-tehnologij-33364015.html', 'company': 'Башкортостанстат', 'position': '29 января • Уфа', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': 50000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b185')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Программист', 'href': 'https://www.superjob.ru/vakansii/programmist-33437653.html', 'company': 'Центр стратегического планирования Минздрава РФ', 'position': '29 января • Москва,Щукинская', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b186')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Ведущий Web-разработчик PHP, JS (full stack)', 'href': 'https://www.superjob.ru/vakansii/veduschij-web-razrabotchik-php-33399983.html', 'company': 'Север Авто М', 'position': '29 января • Москва,Шоссе Энтузиастов, Чкаловская', 'site': 'https://www.superjob.ru', 'finance_min': 150000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b187')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Доцент', 'href': 'https://www.superjob.ru/vakansii/docent-33361314.html', 'company': 'ФГБОУ ВО СПбГАСУ', 'position': '28 января • Санкт-Петербург,Технологический институт I, Технологический институт II', 'site': 'https://www.superjob.ru', 'finance_min': 60000, 'finance_max': 70000, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b188')}
# ERROR, duplicate
# =============================================================
# =============================================================
# {'name': 'Тестировщик (автоматизатор)', 'href': 'https://www.superjob.ru/vakansii/testirovschik-33359565.html', 'company': 'Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве', 'position': '28 января • Санкт-Петербург', 'site': 'https://www.superjob.ru', 'finance_min': 40000, 'finance_max': None, 'valuta': '₽', '_id': ObjectId('5e393ccedb491d142937b189')}
# ERROR, duplicate
# =============================================================

# %%
data = reade_DataBase(vacancy)
print(len(data))
# Out:
# 1868

# %%
data = search_in_DataBase(vacancy, 120000)
df = pd.DataFrame(data)

# %%
df
# Out:
#                           _id  \
# 0    5e393ccddb491d142937a96c
# 1    5e393ccddb491d142937a96f
# 2    5e393ccddb491d142937a972
# 3    5e393ccddb491d142937a982
# 4    5e393ccddb491d142937a985
# ..                        ...
# 305  5e393ccedb491d142937b16c
# 306  5e393ccedb491d142937b17a
# 307  5e393ccedb491d142937b184
# 308  5e393ccedb491d142937b186
# 309  5e393ccedb491d142937b187
#
#                                                   name  \
# 0    Ведущий разработчик Python / Software developm...
# 1                             WEB разработчик, Backend
# 2                                       Data Scientist
# 3        Системный администратор Linux / DevOps/Митино
# 4        Senior Frontend Developer (JavaScript, React)
# ..                                                 ...
# 305                       Старший back-end разработчик
# 306            Администратор Linux (релокейт в Москву)
# 307                Администратор баз данных PostgreSQL
# 308                                        Программист
# 309       Ведущий Web-разработчик PHP, JS (full stack)
#
#                                                   href  \
# 0    https://chelyabinsk.hh.ru/vacancy/34200113?que...
# 1    https://chelyabinsk.hh.ru/vacancy/35650964?que...
# 2    https://chelyabinsk.hh.ru/vacancy/35011897?que...
# 3    https://chelyabinsk.hh.ru/vacancy/35105576?que...
# 4    https://chelyabinsk.hh.ru/vacancy/34746892?que...
# ..                                                 ...
# 305  https://www.superjob.ru/vakansii/starshij-back...
# 306  https://www.superjob.ru/vakansii/administrator...
# 307  https://www.superjob.ru/vakansii/administrator...
# 308  https://www.superjob.ru/vakansii/programmist-3...
# 309  https://www.superjob.ru/vakansii/veduschij-web...
#
#                                                company  \
# 0                                        CATAPULTO.RU
# 1                                         ТОО SOMNIUM
# 2                  HeadHunter::Analytics/Data Science
# 3                                        ООО ТЛ Групп
# 4                                HeadHunter::Frontend
# ..                                                 ...
# 305                                     ВИЗАВИ Консалт
# 306                                    Global Personal
# 307  Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в ...
# 308    Центр стратегического планирования Минздрава РФ
# 309                                       Север Авто М
#
#                                               position  \
# 0                                               Москва
# 1                                           Нур-Султан
# 2                                 Москва, Алексеевская
# 3                              Москва, Митино и еще 1
# 4                                 Москва, Алексеевская
# ..                                                 ...
# 305                                    вчера • Вологда
# 306                        1 февраля • Санкт-Петербург
# 307  29 января • Москва,Сходненская, Волоколамская ...
# 308                       29 января • Москва,Щукинская
# 309   29 января • Москва,Шоссе Энтузиастов, Чкаловская
#
#                         site  finance_min  finance_max valuta
# 0              https://hh.ru     200000.0          NaN   руб.
# 1              https://hh.ru     400000.0     800000.0    KZT
# 2              https://hh.ru     200000.0          NaN   руб.
# 3              https://hh.ru     150000.0     150000.0   руб.
# 4              https://hh.ru     230000.0          NaN   руб.
# ..                       ...          ...          ...    ...
# 305  https://www.superjob.ru     150000.0          NaN      ₽
# 306  https://www.superjob.ru     120000.0     160000.0      ₽
# 307  https://www.superjob.ru          NaN     150000.0      ₽
# 308  https://www.superjob.ru     150000.0          NaN      ₽
# 309  https://www.superjob.ru     150000.0          NaN      ₽
#
# [310 rows x 9 columns]
